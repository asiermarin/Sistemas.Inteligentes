# %% [markdown]
# # Práctica 5

# %% [markdown]
# ## Descripción

# %% [markdown]
# Para comprobar la utilidad de los algoritmos genéticos, vamos a intentar genera el string "Industria 4.0" utilizando un string aleatorio de la misma longitud.
#
# Es decir, partiremos de una población de strings aleatorios con la misma longitud (ej. "AAAAAAAAABA.A"), que irá evolucionando hasta que la mayoría de ellos se parezcan a "Industria 4.0".
#
# - Los genes disponibles son: " abcdefghijklmnñopqrstuvwxyzABCDEFGHIJKLMNÑOPQRSTUVWXYZ1234567890,.-;:_¿?¡!"
#
# - El tamaño de la población es 100
#
# - La reproducción será realizada por el 50% de los individuos más aptos que generarán el 90% de la nueva población.
#
# - Utiliza el método de reproducción que consideres.
#
# - Utiliza algún método de mutación.
#
# - La nueva población estará formada por el 10% más apto de la generación anterior más los nuevos descendientes.

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# Podemos resumir el algoritmo en el siguiente pseudocódigo:
#
# 1) Inicializar población aleatoria.
#
# 2) Determinar la aptitud de la población.
#
# 3) Hasta que la condición de parada sea TRUE:
#
#       a) Escoger padres.
#
#       b) Cruzar y generar nueva población.
#
#       c) Realizar mutación en la población
#
#       d) Determinar la aptitud de la población.
#
#
# La condición de parada será que el mejor individuo tenga una aptitud del 100%

# %% [markdown]
# ## Solución

# %%
import random

TAMANIO_CADENA = 13
POBALCION = 100
GENES_POSIBLES = ' abcdefghijklmnñopqrstuvwxyzABCDEFGHIJKLMNÑOPQRSTUVWXYZ1234567890,.-;:_¿?¡!'
CADENA_OBJETIVO = "Industria 4.0"
PORCENTAJE_POBLACION_HIJOS = 0.9
PORCENTAJE_APTOS_NECESARIA_INICIAL = 0.5
PORCENTAJE_MAS_APTOS = 0.2

class Cromosoma:
    
    def __init__(self, genes, tamanio, genes_padre_1, genes_padre_2):
        self.genes = genes
        self.tamanio = tamanio
        self.aptitud = 0
        self.identificador = hash(self.genes)
        if (genes == CADENA_OBJETIVO):
            self.es_cromosoma_ideal = True
        else:
            self.es_cromosoma_ideal = False
        self.genes_aptos = []
        self.genes_padre_1 = genes_padre_1
        self.genes_padre_2 = genes_padre_2
        self.determinar_aptitud()

    def determinar_aptitud(self):
        ubicacion_gen = 0
        for gen in self.genes:      
            if (gen == CADENA_OBJETIVO[ubicacion_gen]):
                self.aptitud = self.aptitud + 1
                self.genes_aptos.append(ubicacion_gen)
            ubicacion_gen = ubicacion_gen + 1
        print(f"Cromosoma: {self.genes} ------>  Aptitud: {self.aptitud} --- Genes padres:{self.genes_padre_1, self.genes_padre_2}")

def generar_lista_poblacion():
    print("Generando lista")
    poblacion = []
    for i in range(POBALCION):
        cadena = ''.join(random.choice(GENES_POSIBLES) for i in range(TAMANIO_CADENA))
        new_cromosoma = Cromosoma(cadena, TAMANIO_CADENA, None, None)
        poblacion.append(new_cromosoma)
    return poblacion

def devolver_numero_necesario_segun_porcentaje(lista, porcentaje):
    numero_poblacion = len(lista)
    nuemro_necesario = int(numero_poblacion * porcentaje)
    return nuemro_necesario

# Devolvemos los 50 mejores
def devolver_cromosomas_aptos(lista_poblacion):
    print("Devolviendo cromosomas aptos")
    lista_poblacion.sort(key=lambda x: x.aptitud, reverse=True)
    numero_lista_aptos_necesaria = devolver_numero_necesario_segun_porcentaje(lista_poblacion, PORCENTAJE_APTOS_NECESARIA_INICIAL) # 50
    lista_aptos = lista_poblacion[:numero_lista_aptos_necesaria]
    return lista_aptos

def generar_proxima_generacion(lista_cromosomas_aptos, lista_poblacion):
    print("Generando proxima generacion")
    rango_mas_aptos = devolver_numero_necesario_segun_porcentaje(lista_cromosomas_aptos, PORCENTAJE_MAS_APTOS) # 10
    rango_lista_hijos = devolver_numero_necesario_segun_porcentaje(lista_poblacion, PORCENTAJE_POBLACION_HIJOS) # 90
    lista_proxima_generacion = lista_cromosomas_aptos[:rango_mas_aptos] # ya tenemos el 10%
    lista_hijos = reproducir_hijos(lista_cromosomas_aptos, rango_lista_hijos) # Otro 90%
    lista_proxima_generacion.extend(lista_hijos)
    lista_proxima_generacion.sort(key=lambda x: x.aptitud, reverse=True)
    return lista_proxima_generacion

def reproducir_hijos(lista_cromosomas_aptos, rango_lista_hijos):
    lista_hijos = []
    for i in range(rango_lista_hijos):
        cromosoma_padre_1 = lista_cromosomas_aptos[random.randrange(len(lista_cromosomas_aptos))]
        cromosoma_padre_2 = lista_cromosomas_aptos[random.randrange(len(lista_cromosomas_aptos))]
        lista_hijos.append(mutacion(cromosoma_padre_1, cromosoma_padre_2))
    return lista_hijos

def mutacion(cromosoma_padre_1, cromosoma_padre_2):
    genes_mutados = ""
    for ubicacion in range(TAMANIO_CADENA):
        if (ubicacion in cromosoma_padre_1.genes_aptos):
            genes_mutados += cromosoma_padre_1.genes[ubicacion]
        elif (ubicacion in cromosoma_padre_2.genes_aptos):
            genes_mutados += cromosoma_padre_2.genes[ubicacion]
        else:
            genes_mutados +=  random.choice(GENES_POSIBLES)
    cromosoma_hijo = Cromosoma(genes_mutados, TAMANIO_CADENA,cromosoma_padre_1.genes, cromosoma_padre_2.genes)
    return cromosoma_hijo

def algoritmo_genetico():
    cromosoma_ideal = None
    lista_poblacion = generar_lista_poblacion()
    lista_cromosomas_aptos = None
    lista_proxima_generacion = None
    while cromosoma_ideal == None:
        lista_cromosomas_aptos = devolver_cromosomas_aptos(lista_poblacion)  # 50% aptos
        lista_proxima_generacion = generar_proxima_generacion(lista_cromosomas_aptos, lista_poblacion)
        cromosoma_ideal = next((cromosoma for cromosoma in lista_proxima_generacion if cromosoma.genes == CADENA_OBJETIVO), None)
        lista_poblacion.clear()
        lista_poblacion = lista_proxima_generacion.copy()
        lista_cromosomas_aptos.clear()
        lista_proxima_generacion.clear()
    print(cromosoma_ideal.genes)

algoritmo_genetico()
# Out:
# Generando lista
# Cromosoma: A.zp.¡gCK983x ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ¡R¡c.D;MKAT;4 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Jqñ:?9jUypg3: ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: YP!CBwqAghG_0 ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: 649.9pRnuC?VJ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: zeo-q7iNCmn_w ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: wCc1Kvzj_.yPm ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ñ?Ñ4Rt,-3_CL2 ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: !e¡Z¡df7sKMnQ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: W¿UQbzñt DrTÑ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: kHgrBXxgIqyuK ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: tR,iUV1Hlj zA ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 9e0: ñul;9n¡V ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: gj-!idgEArbñ2 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: o1gÑk0LN_NiZa ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: g1BREt.T1UBtu ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: g:62 BJ56!6LW ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: tR6SYX¡TuQx4! ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: OFn6VGJ-XJtTB ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: A1WQANQ XOUB1 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 0NumwT?2YskDP ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: nJ.3-WPFh0zH- ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: mE3G-2A.W N5¡ ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: Ñ!RwG8tÑ:hG?K ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: h?FEuY0n_H7aD ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: T0Rl¡ñKsi;FeQ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 9ANhtPr?Beouv ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: hr!o4?u0gF;¡ñ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ;YbS F:v;Pile ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ;¿¡ol-!El15Wa ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: y0qG596A!0Bcy ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: DMgdQa6ñq5ñt9 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: U;e¿czG4uGvq¡ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: UMty.cGi1-g¡p ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: _5kPyRo_JdTNR ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Px0boMOJMgn;0 ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: EhEcvU!I!6XXF ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 5vc9¡_I1FIdvh ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 4kOo4cD;R;s 6 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ¡Zof?GhtZWk-A ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: FvHlSZlF XdIp ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: qI8zwmw5.LY3O ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: KrP9O?wESmpqn ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: -2Tnjk,X 9fhC ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: OHh5ñz8V!HToy ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: b;Qj0¿8VatPV0 ------>  Aptitud: 2 --- Genes padres:(None, None)
# Cromosoma: Z¡Q .js!UZzQT ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 6XEj:nZ5 ar,- ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ñY6?8ÑiuhigiA ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: QiEU3kGGÑFdPg ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Rh¡oñ:EDÑ¿pv: ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: LUBH4lZO¡hDK; ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Lth-pE8TZRX96 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ;7cGSvrpO6ñc9 ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: WPGLF0_ÑÑgyq  ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 4ÑOsP6mkURt7y ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: I7S1QBx21sRÑq ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: 6Pñt8XmT10dKE ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: qPN2jO8cRh?ci ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: u?y3,DeyBY75G ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: iij!d1HAlxgl- ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Z,dcZDPAcO6_5 ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: F;x84ñ0Geiew_ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: yYyT7UdWFw:C, ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: gBN ;pGY,wmvn ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: zrf:Xaw¿ptm:w ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ox2Orp61A?qdE ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: -ERD1 dÑAz8N4 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: IlbI,Bb;nI!lL ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: cSakÑrVNWvvQA ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: eKW4fIrz5XqjK ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: 9¿YdxVp_MW7rñ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: -zWKEPñ4unZor ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: zl89_uGdc:PuC ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: wwB;a4TGu,TF¿ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: ,hW:DJp:dUDQ: ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: XuNQrkrRlKGVn ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: X7ñiz7Cocñ3ZC ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: nOMP!mp4:61yY ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: St45ijkF¡CXV, ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 9U-U5Jb_bjUlp ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: J,WO¿?kgtzt,r ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 2xLm8rO5ya¡K8 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: YC38AiIÑcg O0 ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: ¡7¡ RY9R6Eñko ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Ve5dDRfS;j4ñi ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: Z?vbkLHG Hz?E ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: Qgg1DxOh.mF3g ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: BnG0m¿c3KOQQo ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: f¡FYb8Q0U-aPk ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: :g5B:.-d3oWiT ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma:  6HÑfTuMSpOVf ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: 3pCFW KñncL1R ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: IBM5mhIÑ_XsrÑ ------>  Aptitud: 1 --- Genes padres:(None, None)
# Cromosoma: MFz61KN7z5.DB ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: JISxlop,7WqXZ ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: H8,H.DyFplK9y ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: pQ1pPAz47Puw9 ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: WhmfCWFZorH¡v ------>  Aptitud: 0 --- Genes padres:(None, None)
# Cromosoma: PEluf-DJtTacc ------>  Aptitud: 1 --- Genes padres:(None, None)
# Devolviendo cromosomas aptos
# Generando proxima generacion
# Cromosoma: KNsZD rx4GcQ. ------>  Aptitud: 1 --- Genes padres:('9ANhtPr?Beouv', 'OFn6VGJ-XJtTB')
# Cromosoma: ,¡li,tXiSDzj: ------>  Aptitud: 2 --- Genes padres:('A1WQANQ XOUB1', 'g1BREt.T1UBtu')
# Cromosoma: 5t5k1¿JTse¡xE ------>  Aptitud: 0 --- Genes padres:('kHgrBXxgIqyuK', 'EhEcvU!I!6XXF')
# Cromosoma: ¿;tz k15K,:?e ------>  Aptitud: 0 --- Genes padres:('o1gÑk0LN_NiZa', 'DMgdQa6ñq5ñt9')
# Cromosoma: Ix7V9xaPgnLgG ------>  Aptitud: 1 --- Genes padres:('649.9pRnuC?VJ', 'I7S1QBx21sRÑq')
# Cromosoma: dViuZ6¿Io;oY¿ ------>  Aptitud: 1 --- Genes padres:('OFn6VGJ-XJtTB', 'PEluf-DJtTacc')
# Cromosoma: ÑS4ACR9Y5Wm2_ ------>  Aptitud: 0 --- Genes padres:('EhEcvU!I!6XXF', '!e¡Z¡df7sKMnQ')
# Cromosoma: kjd9s¡ScYsY?U ------>  Aptitud: 2 --- Genes padres:('hr!o4?u0gF;¡ñ', 'Z,dcZDPAcO6_5')
# Cromosoma: UZt.i:bTJss90 ------>  Aptitud: 1 --- Genes padres:('YC38AiIÑcg O0', 'hr!o4?u0gF;¡ñ')
# Cromosoma: Zfk:?YFsRY6;a ------>  Aptitud: 0 --- Genes padres:('A1WQANQ XOUB1', '0NumwT?2YskDP')
# Cromosoma: IfÑNxV,Ek!TzD ------>  Aptitud: 1 --- Genes padres:('hr!o4?u0gF;¡ñ', 'I7S1QBx21sRÑq')
# Cromosoma: q_ñF_kr0qCd¿9 ------>  Aptitud: 1 --- Genes padres:('h?FEuY0n_H7aD', ';7cGSvrpO6ñc9')
# Cromosoma: I¡wVPPlZozK70 ------>  Aptitud: 2 --- Genes padres:('I7S1QBx21sRÑq', 'Px0boMOJMgn;0')
# Cromosoma: wÑÑ1Iw0JQq:w; ------>  Aptitud: 0 --- Genes padres:('Ñ!RwG8tÑ:hG?K', '_5kPyRo_JdTNR')
# Cromosoma: DhXJÑPuzBfnGu ------>  Aptitud: 0 --- Genes padres:('tR6SYX¡TuQx4!', 'T0Rl¡ñKsi;FeQ')
# Cromosoma: _Wkuqz9D03GÑx ------>  Aptitud: 1 --- Genes padres:('PEluf-DJtTacc', ';YbS F:v;Pile')
# Cromosoma: ¿f.XÑIyi2k-bm ------>  Aptitud: 1 --- Genes padres:('wCc1Kvzj_.yPm', 'UMty.cGi1-g¡p')
# Cromosoma: OW¡¿5s!5:jXK8 ------>  Aptitud: 0 --- Genes padres:('W¿UQbzñt DrTÑ', 'tR6SYX¡TuQx4!')
# Cromosoma: ISdiX Wv7w¡kV ------>  Aptitud: 2 --- Genes padres:('IBM5mhIÑ_XsrÑ', 'wCc1Kvzj_.yPm')
# Cromosoma: 3MlKc-eqtNYzq ------>  Aptitud: 0 --- Genes padres:('A.zp.¡gCK983x', 'Ñ!RwG8tÑ:hG?K')
# Cromosoma: 39l8JoXoR45XM ------>  Aptitud: 0 --- Genes padres:('DMgdQa6ñq5ñt9', 'Jqñ:?9jUypg3:')
# Cromosoma: ?nkW6BÑmGa3tw ------>  Aptitud: 1 --- Genes padres:('h?FEuY0n_H7aD', '!e¡Z¡df7sKMnQ')
# Cromosoma: B?r! 9r6ng 2: ------>  Aptitud: 1 --- Genes padres:('9ANhtPr?Beouv', 'OFn6VGJ-XJtTB')
# Cromosoma: ¿DxFUBK5CkbWs ------>  Aptitud: 0 --- Genes padres:('5vc9¡_I1FIdvh', 'OFn6VGJ-XJtTB')
# Cromosoma: K1M2I_kHl L5y ------>  Aptitud: 1 --- Genes padres:('mE3G-2A.W N5¡', 'kHgrBXxgIqyuK')
# Cromosoma: J4BVY-16tnHLj ------>  Aptitud: 0 --- Genes padres:('U;e¿czG4uGvq¡', 'Jqñ:?9jUypg3:')
# Cromosoma: I8 3¿ñs0J_1-? ------>  Aptitud: 1 --- Genes padres:('0NumwT?2YskDP', 'IlbI,Bb;nI!lL')
# Cromosoma: I!TFfxAy?LfZT ------>  Aptitud: 1 --- Genes padres:('tR6SYX¡TuQx4!', 'IBM5mhIÑ_XsrÑ')
# Cromosoma: CzF:Qryi84RbI ------>  Aptitud: 1 --- Genes padres:('UMty.cGi1-g¡p', 'U;e¿czG4uGvq¡')
# Cromosoma: ¡Xwl8to0oPQQ¿ ------>  Aptitud: 1 --- Genes padres:('g1BREt.T1UBtu', 'y0qG596A!0Bcy')
# Cromosoma: u4ruFt2J.hHwC ------>  Aptitud: 2 --- Genes padres:('gj-!idgEArbñ2', 'EhEcvU!I!6XXF')
# Cromosoma: IgÑnLQB ,p¿ng ------>  Aptitud: 1 --- Genes padres:('EhEcvU!I!6XXF', 'IBM5mhIÑ_XsrÑ')
# Cromosoma: S¿8ÑJ:rZXakdp ------>  Aptitud: 1 --- Genes padres:('XuNQrkrRlKGVn', '!e¡Z¡df7sKMnQ')
# Cromosoma: 4iMqutk¡?P4o? ------>  Aptitud: 2 --- Genes padres:('g1BREt.T1UBtu', 'Ve5dDRfS;j4ñi')
# Cromosoma: p8;0¡?;wSa,i; ------>  Aptitud: 0 --- Genes padres:('g:62 BJ56!6LW', 'U;e¿czG4uGvq¡')
# Cromosoma: s_6Jm60lpiIN0 ------>  Aptitud: 1 --- Genes padres:('h?FEuY0n_H7aD', 'Px0boMOJMgn;0')
# Cromosoma: 2_vrwz rw-sM_ ------>  Aptitud: 0 --- Genes padres:('5vc9¡_I1FIdvh', 'DMgdQa6ñq5ñt9')
# Cromosoma: rS-h?X?C¡wZ¡0 ------>  Aptitud: 1 --- Genes padres:('YP!CBwqAghG_0', '_5kPyRo_JdTNR')
# Cromosoma: TÑhXbUx7o,PyA ------>  Aptitud: 0 --- Genes padres:('DMgdQa6ñq5ñt9', '9e0: ñul;9n¡V')
# Cromosoma: :B,ST9Pbxt-I9 ------>  Aptitud: 0 --- Genes padres:('649.9pRnuC?VJ', 'A1WQANQ XOUB1')
# Cromosoma: 0FdSXbZchX19o ------>  Aptitud: 1 --- Genes padres:('A1WQANQ XOUB1', 'g:62 BJ56!6LW')
# Cromosoma: y;zR9Mr:DN83  ------>  Aptitud: 1 --- Genes padres:('649.9pRnuC?VJ', '9ANhtPr?Beouv')
# Cromosoma: AxKpSYrhk!_JG ------>  Aptitud: 1 --- Genes padres:('_5kPyRo_JdTNR', 'XuNQrkrRlKGVn')
# Cromosoma: ,6LG80lukX5ET ------>  Aptitud: 0 --- Genes padres:('DMgdQa6ñq5ñt9', '_5kPyRo_JdTNR')
# Cromosoma: 5cKFTZ5nLPNÑ0 ------>  Aptitud: 1 --- Genes padres:('YP!CBwqAghG_0', 'nJ.3-WPFh0zH-')
# Cromosoma: CgtbrsEexPU91 ------>  Aptitud: 0 --- Genes padres:('9e0: ñul;9n¡V', ';YbS F:v;Pile')
# Cromosoma: bÑoJp Gr;t4QP ------>  Aptitud: 1 --- Genes padres:('Ñ!RwG8tÑ:hG?K', 'g:62 BJ56!6LW')
# Cromosoma: gOAh;6z,jcQZX ------>  Aptitud: 0 --- Genes padres:('Jqñ:?9jUypg3:', '9e0: ñul;9n¡V')
# Cromosoma: 7bj7OE63FiE?, ------>  Aptitud: 0 --- Genes padres:('hr!o4?u0gF;¡ñ', 'y0qG596A!0Bcy')
# Cromosoma: rP_RyVrtaaBz0 ------>  Aptitud: 3 --- Genes padres:('hr!o4?u0gF;¡ñ', 'b;Qj0¿8VatPV0')
# Cromosoma: FfRq1Gb,UmFz0 ------>  Aptitud: 1 --- Genes padres:('9e0: ñul;9n¡V', 'Px0boMOJMgn;0')
# Cromosoma: .3xuK¿O;-YT7k ------>  Aptitud: 1 --- Genes padres:('PEluf-DJtTacc', 'A.zp.¡gCK983x')
# Cromosoma: EAILm PHxMju0 ------>  Aptitud: 1 --- Genes padres:('OFn6VGJ-XJtTB', 'Px0boMOJMgn;0')
# Cromosoma: wQWusNrjvD:T! ------>  Aptitud: 3 --- Genes padres:('PEluf-DJtTacc', '9ANhtPr?Beouv')
# Cromosoma: I37i-IcU0eCO0 ------>  Aptitud: 2 --- Genes padres:('IlbI,Bb;nI!lL', 'YC38AiIÑcg O0')
# Cromosoma: IgbsKvÑikKZs0 ------>  Aptitud: 3 --- Genes padres:('9e0: ñul;9n¡V', 'IlbI,Bb;nI!lL')
# Cromosoma: -HSzR0rh7IbX0 ------>  Aptitud: 2 --- Genes padres:('!e¡Z¡df7sKMnQ', 'YP!CBwqAghG_0')
# Cromosoma: I8LPw8qsSx?OW ------>  Aptitud: 1 --- Genes padres:('IlbI,Bb;nI!lL', 'A.zp.¡gCK983x')
# Cromosoma: OLNpJtIM6a_Ix ------>  Aptitud: 1 --- Genes padres:('!e¡Z¡df7sKMnQ', 'g1BREt.T1UBtu')
# Cromosoma: rjEkft9!4KI¿0 ------>  Aptitud: 2 --- Genes padres:('g1BREt.T1UBtu', 'Px0boMOJMgn;0')
# Cromosoma: ¡nñHL85,:!ñot ------>  Aptitud: 1 --- Genes padres:('_5kPyRo_JdTNR', '_5kPyRo_JdTNR')
# Cromosoma: dpZhvrrgkdzg0 ------>  Aptitud: 2 --- Genes padres:('wCc1Kvzj_.yPm', ';7cGSvrpO6ñc9')
# Cromosoma: NA4BCIIv8WJwG ------>  Aptitud: 0 --- Genes padres:(';YbS F:v;Pile', 'tR,iUV1Hlj zA')
# Cromosoma: IliFbILTouh3h ------>  Aptitud: 1 --- Genes padres:('IBM5mhIÑ_XsrÑ', '649.9pRnuC?VJ')
# Cromosoma: bPÑHJ1x KDqco ------>  Aptitud: 0 --- Genes padres:('T0Rl¡ñKsi;FeQ', '5vc9¡_I1FIdvh')
# Cromosoma: 7AGuNu.RS.yñG ------>  Aptitud: 1 --- Genes padres:('PEluf-DJtTacc', 'h?FEuY0n_H7aD')
# Cromosoma:  DKO;7r2U,xij ------>  Aptitud: 1 --- Genes padres:('y0qG596A!0Bcy', 'eKW4fIrz5XqjK')
# Cromosoma: Tj1u:Loxh-HHQ ------>  Aptitud: 1 --- Genes padres:('PEluf-DJtTacc', 'nJ.3-WPFh0zH-')
# Cromosoma: 6cWuÑK:FPBaKh ------>  Aptitud: 1 --- Genes padres:('PEluf-DJtTacc', 'wCc1Kvzj_.yPm')
# Cromosoma: ñ;OX0QroXñt1T ------>  Aptitud: 1 --- Genes padres:('T0Rl¡ñKsi;FeQ', 'XuNQrkrRlKGVn')
# Cromosoma: eUVfd4sOdZ6gy ------>  Aptitud: 0 --- Genes padres:('y0qG596A!0Bcy', 'kHgrBXxgIqyuK')
# Cromosoma: 7JRO!jrdL¡g70 ------>  Aptitud: 2 --- Genes padres:('Px0boMOJMgn;0', 'eKW4fIrz5XqjK')
# Cromosoma: -6UeZ8rqts¿3! ------>  Aptitud: 1 --- Genes padres:('wCc1Kvzj_.yPm', ';7cGSvrpO6ñc9')
# Cromosoma: Zn1!j0r¿Zijk3 ------>  Aptitud: 2 --- Genes padres:('BnG0m¿c3KOQQo', '9ANhtPr?Beouv')
# Cromosoma: lntj07jv¿I;z4 ------>  Aptitud: 1 --- Genes padres:('W¿UQbzñt DrTÑ', 'BnG0m¿c3KOQQo')
# Cromosoma: 2WR-NcÑfQ387F ------>  Aptitud: 0 --- Genes padres:('_5kPyRo_JdTNR', 'T0Rl¡ñKsi;FeQ')
# Cromosoma: dRLtVUNfXC¿m: ------>  Aptitud: 0 --- Genes padres:('kHgrBXxgIqyuK', 'EhEcvU!I!6XXF')
# Cromosoma: Ccd2¡tQQLvHrb ------>  Aptitud: 2 --- Genes padres:('5vc9¡_I1FIdvh', 'Z,dcZDPAcO6_5')
# Cromosoma: r2vJYarunm4Yt ------>  Aptitud: 2 --- Genes padres:('Ve5dDRfS;j4ñi', ';7cGSvrpO6ñc9')
# Cromosoma: _kTM-Cr727fVr ------>  Aptitud: 1 --- Genes padres:('tR6SYX¡TuQx4!', ';7cGSvrpO6ñc9')
# Cromosoma: RdX¿HADAe¿ wi ------>  Aptitud: 0 --- Genes padres:('U;e¿czG4uGvq¡', '_5kPyRo_JdTNR')
# Cromosoma: I.; :kPMdCH9D ------>  Aptitud: 1 --- Genes padres:('gj-!idgEArbñ2', 'I7S1QBx21sRÑq')
# Cromosoma: nz:uZP3Y7YTw0 ------>  Aptitud: 2 --- Genes padres:('PEluf-DJtTacc', 'YP!CBwqAghG_0')
# Cromosoma: ÑJ-l1B¡¿oF670 ------>  Aptitud: 1 --- Genes padres:('tR,iUV1Hlj zA', 'o1gÑk0LN_NiZa')
# Cromosoma: D¡a1E0rEojS?0 ------>  Aptitud: 2 --- Genes padres:('YP!CBwqAghG_0', 'XuNQrkrRlKGVn')
# Cromosoma: adñ¿15rQ!IFYñ ------>  Aptitud: 1 --- Genes padres:('zeo-q7iNCmn_w', 'EhEcvU!I!6XXF')
# Cromosoma: MnzCaJrG0IM9K ------>  Aptitud: 2 --- Genes padres:(';7cGSvrpO6ñc9', 'hr!o4?u0gF;¡ñ')
# Cromosoma: WjTPEN5Bww ;¡ ------>  Aptitud: 0 --- Genes padres:('y0qG596A!0Bcy', 'EhEcvU!I!6XXF')
# Cromosoma: ff-5eP7,jG rU ------>  Aptitud: 0 --- Genes padres:('EhEcvU!I!6XXF', 'g:62 BJ56!6LW')
# Cromosoma: !FV3,So1P  b0 ------>  Aptitud: 2 --- Genes padres:('mE3G-2A.W N5¡', 'YC38AiIÑcg O0')
# Devolviendo cromosomas aptos
# Generando proxima generacion
# Cromosoma: In7Yñ1rWsÑzCs ------>  Aptitud: 3 --- Genes padres:('Ix7V9xaPgnLgG', 'Zn1!j0r¿Zijk3')
# Cromosoma: lñdALt6_L?IAX ------>  Aptitud: 2 --- Genes padres:('ñ?Ñ4Rt,-3_CL2', 'Ccd2¡tQQLvHrb')
# Cromosoma: AndO4grJyhPp5 ------>  Aptitud: 3 --- Genes padres:('MnzCaJrG0IM9K', ';7cGSvrpO6ñc9')
# Cromosoma: Indd.PrI04M24 ------>  Aptitud: 4 --- Genes padres:('ISdiX Wv7w¡kV', 'KNsZD rx4GcQ.')
# Cromosoma: o0JnlqrUa04C0 ------>  Aptitud: 4 --- Genes padres:('r2vJYarunm4Yt', 'b;Qj0¿8VatPV0')
# Cromosoma: IUd?QtviJMgc5 ------>  Aptitud: 4 --- Genes padres:(',¡li,tXiSDzj:', 'Ccd2¡tQQLvHrb')
# Cromosoma: Isdluz0r¡S9;0 ------>  Aptitud: 3 --- Genes padres:('rS-h?X?C¡wZ¡0', 'ISdiX Wv7w¡kV')
# Cromosoma: o2au8tJ2Zh6j0 ------>  Aptitud: 3 --- Genes padres:('nz:uZP3Y7YTw0', 'g1BREt.T1UBtu')
# Cromosoma: IJJñuprPkb45H ------>  Aptitud: 3 --- Genes padres:('r2vJYarunm4Yt', 'IfÑNxV,Ek!TzD')
# Cromosoma: PnU;pgr?M_6Jh ------>  Aptitud: 2 --- Genes padres:(';7cGSvrpO6ñc9', '?nkW6BÑmGa3tw')
# Cromosoma: Q7sÑ9tYlaL1J0 ------>  Aptitud: 3 --- Genes padres:('¡Xwl8to0oPQQ¿', 'b;Qj0¿8VatPV0')
# Cromosoma: I Vu blH0N?E0 ------>  Aptitud: 3 --- Genes padres:('I¡wVPPlZozK70', '_Wkuqz9D03GÑx')
# Cromosoma: :n5uWtrAF_:iv ------>  Aptitud: 4 --- Genes padres:('u4ruFt2J.hHwC', 'MnzCaJrG0IM9K')
# Cromosoma: Ir7uTV3ip45g0 ------>  Aptitud: 4 --- Genes padres:('IgbsKvÑikKZs0', '_Wkuqz9D03GÑx')
# Cromosoma: R3d,sOYXG !zR ------>  Aptitud: 3 --- Genes padres:('mE3G-2A.W N5¡', 'kjd9s¡ScYsY?U')
# Cromosoma: IkñXVt!;SN4ñQ ------>  Aptitud: 3 --- Genes padres:('ñ?Ñ4Rt,-3_CL2', 'IfÑNxV,Ek!TzD')
# Cromosoma: I c;7ñ!i;QL89 ------>  Aptitud: 2 --- Genes padres:('¿f.XÑIyi2k-bm', 'Ix7V9xaPgnLgG')
# Cromosoma: S8OEIt_Mz Ot0 ------>  Aptitud: 3 --- Genes padres:('!FV3,So1P  b0', '¡Xwl8to0oPQQ¿')
# Cromosoma: tMZusarIFSqQ0 ------>  Aptitud: 4 --- Genes padres:('rS-h?X?C¡wZ¡0', 'wQWusNrjvD:T!')
# Cromosoma: IlAuYd55Aycr7 ------>  Aptitud: 2 --- Genes padres:('dViuZ6¿Io;oY¿', 'IgÑnLQB ,p¿ng')
# Cromosoma: ImJf,RrbcmLAr ------>  Aptitud: 2 --- Genes padres:('IgÑnLQB ,p¿ng', ';7cGSvrpO6ñc9')
# Cromosoma: ,U;uPZsizHB¿h ------>  Aptitud: 2 --- Genes padres:('_Wkuqz9D03GÑx', 'CzF:Qryi84RbI')
# Cromosoma: InXC¡Ari8lpd0 ------>  Aptitud: 5 --- Genes padres:('Zn1!j0r¿Zijk3', 'IgbsKvÑikKZs0')
# Cromosoma: :ldpNtrHOqW-z ------>  Aptitud: 3 --- Genes padres:('Ccd2¡tQQLvHrb', ';7cGSvrpO6ñc9')
# Cromosoma: 0nJY_tr!t mBm ------>  Aptitud: 4 --- Genes padres:('mE3G-2A.W N5¡', 'MnzCaJrG0IM9K')
# Cromosoma: ?DWietCu684U0 ------>  Aptitud: 3 --- Genes padres:('s_6Jm60lpiIN0', '4iMqutk¡?P4o?')
# Cromosoma: Q eSYprQ54aT0 ------>  Aptitud: 2 --- Genes padres:('dpZhvrrgkdzg0', 'B?r! 9r6ng 2:')
# Cromosoma: clOa8qr1m1nyx ------>  Aptitud: 1 --- Genes padres:('S¿8ÑJ:rZXakdp', 'q_ñF_kr0qCd¿9')
# Cromosoma: vqqyHt_iO8xh0 ------>  Aptitud: 3 --- Genes padres:('rjEkft9!4KI¿0', 'UMty.cGi1-g¡p')
# Cromosoma: g.h7btl3xIjU0 ------>  Aptitud: 2 --- Genes padres:('rS-h?X?C¡wZ¡0', 'rjEkft9!4KI¿0')
# Cromosoma: .-5FitrSÑM4Ñp ------>  Aptitud: 3 --- Genes padres:('4iMqutk¡?P4o?', 'q_ñF_kr0qCd¿9')
# Cromosoma: IvÑbBkPi-xwñ0 ------>  Aptitud: 3 --- Genes padres:('¿f.XÑIyi2k-bm', 'IgbsKvÑikKZs0')
# Cromosoma: ,Szustrh3ñzP0 ------>  Aptitud: 5 --- Genes padres:('rjEkft9!4KI¿0', 'wQWusNrjvD:T!')
# Cromosoma: Añ_u3Z?49 Ey0 ------>  Aptitud: 3 --- Genes padres:('K1M2I_kHl L5y', 'nz:uZP3Y7YTw0')
# Cromosoma: WUTTsñrcVNGb0 ------>  Aptitud: 3 --- Genes padres:('9ANhtPr?Beouv', 'UZt.i:bTJss90')
# Cromosoma: IiUhatDkvndQR ------>  Aptitud: 2 --- Genes padres:('I7S1QBx21sRÑq', 'g1BREt.T1UBtu')
# Cromosoma: Wn:.¿Ñr3b Et0 ------>  Aptitud: 4 --- Genes padres:('!FV3,So1P  b0', 'Zn1!j0r¿Zijk3')
# Cromosoma: YÑpnT9rlR;sG0 ------>  Aptitud: 2 --- Genes padres:('B?r! 9r6ng 2:', 'YP!CBwqAghG_0')
# Cromosoma: Ñk-sZV7ijhh90 ------>  Aptitud: 2 --- Genes padres:('CzF:Qryi84RbI', 'UZt.i:bTJss90')
# Cromosoma: IW4QÑe6HXiGu0 ------>  Aptitud: 2 --- Genes padres:('rS-h?X?C¡wZ¡0', 'I!TFfxAy?LfZT')
# Cromosoma: Gn-pD;rK4.kK0 ------>  Aptitud: 3 --- Genes padres:('7JRO!jrdL¡g70', '?nkW6BÑmGa3tw')
# Cromosoma: k,uwStr8WAc3! ------>  Aptitud: 2 --- Genes padres:(';7cGSvrpO6ñc9', 'g1BREt.T1UBtu')
# Cromosoma: Ip!4GtFi1pY;z ------>  Aptitud: 3 --- Genes padres:('Ix7V9xaPgnLgG', ',¡li,tXiSDzj:')
# Cromosoma: XQHujPS4TwME0 ------>  Aptitud: 2 --- Genes padres:('UZt.i:bTJss90', 'nz:uZP3Y7YTw0')
# Cromosoma: fnf9ror8ñ0QdB ------>  Aptitud: 2 --- Genes padres:(';7cGSvrpO6ñc9', '?nkW6BÑmGa3tw')
# Cromosoma: tn0uw0Si-ÑGs9 ------>  Aptitud: 3 --- Genes padres:('dViuZ6¿Io;oY¿', '¿f.XÑIyi2k-bm')
# Cromosoma: 0A¡5¿DA4k94e0 ------>  Aptitud: 2 --- Genes padres:('s_6Jm60lpiIN0', 'YP!CBwqAghG_0')
# Cromosoma: XnCmVerSTzNIr ------>  Aptitud: 2 --- Genes padres:('?nkW6BÑmGa3tw', 'MnzCaJrG0IM9K')
# Cromosoma: IVoz¡tli!;u!b ------>  Aptitud: 3 --- Genes padres:(',¡li,tXiSDzj:', 'IgÑnLQB ,p¿ng')
# Cromosoma: -:vait!iPB0d? ------>  Aptitud: 2 --- Genes padres:('g1BREt.T1UBtu', '¡Xwl8to0oPQQ¿')
# Cromosoma: ItXAylr0o;aT0 ------>  Aptitud: 3 --- Genes padres:('7JRO!jrdL¡g70', 'I¡wVPPlZozK70')
# Cromosoma: I _,AIi7Y_j?0 ------>  Aptitud: 2 --- Genes padres:('IfÑNxV,Ek!TzD', 'YP!CBwqAghG_0')
# Cromosoma: I1jt¿RyhpY9E0 ------>  Aptitud: 2 --- Genes padres:('rS-h?X?C¡wZ¡0', 'I7S1QBx21sRÑq')
# Cromosoma: S_.u:dsioLu-5 ------>  Aptitud: 2 --- Genes padres:('_Wkuqz9D03GÑx', 'CzF:Qryi84RbI')
# Cromosoma: 6gdtLtTO-¿PV0 ------>  Aptitud: 3 --- Genes padres:('Ccd2¡tQQLvHrb', 'UZt.i:bTJss90')
# Cromosoma: 5;RuDtrHkxr90 ------>  Aptitud: 4 --- Genes padres:('rjEkft9!4KI¿0', 'dpZhvrrgkdzg0')
# Cromosoma: ;1au8tQLN jz0 ------>  Aptitud: 4 --- Genes padres:('ñ?Ñ4Rt,-3_CL2', '!FV3,So1P  b0')
# Cromosoma: IF-usKrW!QTC0 ------>  Aptitud: 5 --- Genes padres:('I37i-IcU0eCO0', 'wQWusNrjvD:T!')
# Cromosoma: Iygpx Wizxjf0 ------>  Aptitud: 3 --- Genes padres:('IgbsKvÑikKZs0', 's_6Jm60lpiIN0')
# Cromosoma: In ;ssr2rqIaI ------>  Aptitud: 4 --- Genes padres:('I!TFfxAy?LfZT', 'Zn1!j0r¿Zijk3')
# Cromosoma: onousrrcrrLLV ------>  Aptitud: 4 --- Genes padres:('?nkW6BÑmGa3tw', 'wQWusNrjvD:T!')
# Cromosoma: InFkI4r26ZPo0 ------>  Aptitud: 4 --- Genes padres:('Zn1!j0r¿Zijk3', 'I¡wVPPlZozK70')
# Cromosoma: I_X5CtRBpZ4ye ------>  Aptitud: 3 --- Genes padres:('4iMqutk¡?P4o?', 'Ix7V9xaPgnLgG')
# Cromosoma: E?hi8mr?hY7-0 ------>  Aptitud: 2 --- Genes padres:('s_6Jm60lpiIN0', 'dpZhvrrgkdzg0')
# Cromosoma: hZpE.PrXZst60 ------>  Aptitud: 2 --- Genes padres:('-HSzR0rh7IbX0', 'UZt.i:bTJss90')
# Cromosoma: u2LS8IrEJx4Y0 ------>  Aptitud: 3 --- Genes padres:('r2vJYarunm4Yt', 'dpZhvrrgkdzg0')
# Cromosoma: oJNuC8rQo?6W0 ------>  Aptitud: 3 --- Genes padres:('-HSzR0rh7IbX0', '_Wkuqz9D03GÑx')
# Cromosoma: I4dV¡frJn7.UÑ ------>  Aptitud: 3 --- Genes padres:('q_ñF_kr0qCd¿9', 'ISdiX Wv7w¡kV')
# Cromosoma: pÑdYxth8;tw90 ------>  Aptitud: 3 --- Genes padres:('rS-h?X?C¡wZ¡0', 'Ccd2¡tQQLvHrb')
# Cromosoma: I-zZfÑu6X :;C ------>  Aptitud: 2 --- Genes padres:('Ix7V9xaPgnLgG', 'mE3G-2A.W N5¡')
# Cromosoma: :VQWPtr2a9V:0 ------>  Aptitud: 4 --- Genes padres:('¡Xwl8to0oPQQ¿', 'dpZhvrrgkdzg0')
# Cromosoma: Ic:;O ruqwRb0 ------>  Aptitud: 3 --- Genes padres:('IgÑnLQB ,p¿ng', 'D¡a1E0rEojS?0')
# Cromosoma: b0dAPtrADÑ-.0 ------>  Aptitud: 5 --- Genes padres:('D¡a1E0rEojS?0', 'Ccd2¡tQQLvHrb')
# Cromosoma: CT7DSDr-.al,i ------>  Aptitud: 1 --- Genes padres:('q_ñF_kr0qCd¿9', 'B?r! 9r6ng 2:')
# Cromosoma: fjdJst;KTV4QH ------>  Aptitud: 4 --- Genes padres:('kjd9s¡ScYsY?U', '4iMqutk¡?P4o?')
# Cromosoma: TnA1z!r,mUqfn ------>  Aptitud: 2 --- Genes padres:('Zn1!j0r¿Zijk3', 'Zn1!j0r¿Zijk3')
# Cromosoma: rF_usrr_zrXJ0 ------>  Aptitud: 4 --- Genes padres:('-HSzR0rh7IbX0', 'wQWusNrjvD:T!')
# Cromosoma: ÑIJRCartp8nL0 ------>  Aptitud: 2 --- Genes padres:('D¡a1E0rEojS?0', 'D¡a1E0rEojS?0')
# Cromosoma: xneHiTr6bj 50 ------>  Aptitud: 3 --- Genes padres:('dpZhvrrgkdzg0', '?nkW6BÑmGa3tw')
# Cromosoma: Iwriok5Ma7xw0 ------>  Aptitud: 3 --- Genes padres:('b;Qj0¿8VatPV0', 'IgÑnLQB ,p¿ng')
# Cromosoma: I6qcg:M2jxmP0 ------>  Aptitud: 2 --- Genes padres:('rS-h?X?C¡wZ¡0', 'I7S1QBx21sRÑq')
# Cromosoma: jO-¡¡tr_6AHS0 ------>  Aptitud: 3 --- Genes padres:('-HSzR0rh7IbX0', 'ñ?Ñ4Rt,-3_CL2')
# Cromosoma: INziC6dBKhÑH0 ------>  Aptitud: 2 --- Genes padres:('rS-h?X?C¡wZ¡0', 'IgÑnLQB ,p¿ng')
# Cromosoma: IJC T9r5Hñfp0 ------>  Aptitud: 3 --- Genes padres:('I37i-IcU0eCO0', '9ANhtPr?Beouv')
# Cromosoma: Xn,XNJrsA:U4c ------>  Aptitud: 2 --- Genes padres:('Zn1!j0r¿Zijk3', 'q_ñF_kr0qCd¿9')
# Cromosoma: IJd0!TeJM;ñS0 ------>  Aptitud: 3 --- Genes padres:('I¡wVPPlZozK70', 'ISdiX Wv7w¡kV')
# Cromosoma: 3!4.-1rxIiWk0 ------>  Aptitud: 2 --- Genes padres:('s_6Jm60lpiIN0', 'B?r! 9r6ng 2:')
# Cromosoma: s2 H5tCfa9Xh0 ------>  Aptitud: 3 --- Genes padres:('b;Qj0¿8VatPV0', 'rjEkft9!4KI¿0')
# Cromosoma: 6pmÑMDÑ0h HA0 ------>  Aptitud: 2 --- Genes padres:('rS-h?X?C¡wZ¡0', '!FV3,So1P  b0')
# Cromosoma: IqMzPADia8R;0 ------>  Aptitud: 4 --- Genes padres:('b;Qj0¿8VatPV0', 'IgbsKvÑikKZs0')
# Devolviendo cromosomas aptos
# Generando proxima generacion
# Cromosoma: ICd:ktxiaHNK0 ------>  Aptitud: 6 --- Genes padres:('Q7sÑ9tYlaL1J0', 'IUd?QtviJMgc5')
# Cromosoma: Ibdustrij9AT0 ------>  Aptitud: 8 --- Genes padres:('Ip!4GtFi1pY;z', 'tMZusarIFSqQ0')
# Cromosoma: 4n7usYrwO Sk0 ------>  Aptitud: 6 --- Genes padres:('Wn:.¿Ñr3b Et0', 'tMZusarIFSqQ0')
# Cromosoma: IGBu?ñ!i36bY0 ------>  Aptitud: 4 --- Genes padres:('IvÑbBkPi-xwñ0', 'Ir7uTV3ip45g0')
# Cromosoma: 7rGustr-aYNP0 ------>  Aptitud: 6 --- Genes padres:(':VQWPtr2a9V:0', 'wQWusNrjvD:T!')
# Cromosoma: IbdD,trxpd4O0 ------>  Aptitud: 6 --- Genes padres:('IJJñuprPkb45H', '6gdtLtTO-¿PV0')
# Cromosoma: uDdubtruNy,.0 ------>  Aptitud: 6 --- Genes padres:('b0dAPtrADÑ-.0', 'o2au8tJ2Zh6j0')
# Cromosoma: INguÑtrFf 4a0 ------>  Aptitud: 7 --- Genes padres:(';1au8tQLN jz0', 'IJJñuprPkb45H')
# Cromosoma: 4nFuytYi90400 ------>  Aptitud: 6 --- Genes padres:('?DWietCu684U0', 'tn0uw0Si-ÑGs9')
# Cromosoma: ¿nnuStr;N1aj0 ------>  Aptitud: 5 --- Genes padres:('Gn-pD;rK4.kK0', 'o2au8tJ2Zh6j0')
# Cromosoma: INduptfi1 ET0 ------>  Aptitud: 7 --- Genes padres:('Añ_u3Z?49 Ey0', 'IUd?QtviJMgc5')
# Cromosoma: IqLuvhrixd4H0 ------>  Aptitud: 6 --- Genes padres:('Ir7uTV3ip45g0', 'IJJñuprPkb45H')
# Cromosoma: IIPB_tXicJ4¡0 ------>  Aptitud: 5 --- Genes padres:('IvÑbBkPi-xwñ0', '?DWietCu684U0')
# Cromosoma: InqVstrTÑA4dZ ------>  Aptitud: 6 --- Genes padres:('.-5FitrSÑM4Ñp', 'In ;ssr2rqIaI')
# Cromosoma: Ix¿ustriñ8GF0 ------>  Aptitud: 7 --- Genes padres:('IgbsKvÑikKZs0', ',Szustrh3ñzP0')
# Cromosoma: N5YusKrñ: 6¡0 ------>  Aptitud: 5 --- Genes padres:('tMZusarIFSqQ0', 'Añ_u3Z?49 Ey0')
# Cromosoma: In8c.Lri¿q7h0 ------>  Aptitud: 5 --- Genes padres:('InFkI4r26ZPo0', 'InXC¡Ari8lpd0')
# Cromosoma: IncusñrQTX0H0 ------>  Aptitud: 6 --- Genes padres:('IF-usKrW!QTC0', 'In ;ssr2rqIaI')
# Cromosoma: Indakjr2NB490 ------>  Aptitud: 6 --- Genes padres:('u2LS8IrEJx4Y0', 'Indd.PrI04M24')
# Cromosoma: IYWus_rU. aO0 ------>  Aptitud: 6 --- Genes padres:('IF-usKrW!QTC0', 'Añ_u3Z?49 Ey0')
# Cromosoma: InCusUrb;4Og0 ------>  Aptitud: 6 --- Genes padres:('In7Yñ1rWsÑzCs', 'IF-usKrW!QTC0')
# Cromosoma: I X.vtriq0580 ------>  Aptitud: 5 --- Genes padres:('ItXAylr0o;aT0', 'IVoz¡tli!;u!b')
# Cromosoma: Inr!ttriLHu5N ------>  Aptitud: 5 --- Genes padres:('IVoz¡tli!;u!b', 'In7Yñ1rWsÑzCs')
# Cromosoma: tIdQMtMGR  u0 ------>  Aptitud: 4 --- Genes padres:('S8OEIt_Mz Ot0', '6gdtLtTO-¿PV0')
# Cromosoma: IWzustriE9ZM0 ------>  Aptitud: 7 --- Genes padres:('rF_usrr_zrXJ0', 'Ip!4GtFi1pY;z')
# Cromosoma: In!3sVriJ Q¿0 ------>  Aptitud: 7 --- Genes padres:('In ;ssr2rqIaI', 'InXC¡Ari8lpd0')
# Cromosoma: :nf-Ytrda zf0 ------>  Aptitud: 6 --- Genes padres:('Q7sÑ9tYlaL1J0', 'Wn:.¿Ñr3b Et0')
# Cromosoma: tq5udtrna YM0 ------>  Aptitud: 6 --- Genes padres:('rP_RyVrtaaBz0', ';1au8tQLN jz0')
# Cromosoma: IuQustria00T0 ------>  Aptitud: 8 --- Genes padres:(',Szustrh3ñzP0', 'IqMzPADia8R;0')
# Cromosoma: R5Dus¿r c Eu0 ------>  Aptitud: 5 --- Genes padres:('Añ_u3Z?49 Ey0', 'tMZusarIFSqQ0')
# Cromosoma: 3n:uBtNi¿ 3V0 ------>  Aptitud: 6 --- Genes padres:('S8OEIt_Mz Ot0', 'tn0uw0Si-ÑGs9')
# Cromosoma: InñfRtNiex_G0 ------>  Aptitud: 5 --- Genes padres:('IvÑbBkPi-xwñ0', 'IVoz¡tli!;u!b')
# Cromosoma: InQuitriS 6A0 ------>  Aptitud: 8 --- Genes padres:('Ir7uTV3ip45g0', '0nJY_tr!t mBm')
# Cromosoma: I97Y7sriaN4Ñ0 ------>  Aptitud: 6 --- Genes padres:('o0JnlqrUa04C0', 'Iygpx Wizxjf0')
# Cromosoma: I6dñsZhXc cL0 ------>  Aptitud: 5 --- Genes padres:('Isdluz0r¡S9;0', 'R3d,sOYXG !zR')
# Cromosoma: KnWu_tri;¡zs6 ------>  Aptitud: 5 --- Genes padres:('tn0uw0Si-ÑGs9', ':n5uWtrAF_:iv')
# Cromosoma: dnEustro. Kq0 ------>  Aptitud: 7 --- Genes padres:('0nJY_tr!t mBm', ',Szustrh3ñzP0')
# Cromosoma: ¿ndwOtrnf 7R0 ------>  Aptitud: 6 --- Genes padres:('6gdtLtTO-¿PV0', '0nJY_tr!t mBm')
# Cromosoma: InduOErZ4EI30 ------>  Aptitud: 6 --- Genes padres:('Indd.PrI04M24', 'I Vu blH0N?E0')
# Cromosoma: ;VOustrifFT70 ------>  Aptitud: 6 --- Genes padres:(',Szustrh3ñzP0', 'vqqyHt_iO8xh0')
# Cromosoma: Q Pu3tryPo 90 ------>  Aptitud: 4 --- Genes padres:('5;RuDtrHkxr90', 'o2au8tJ2Zh6j0')
# Cromosoma: kndhsmram NF0 ------>  Aptitud: 6 --- Genes padres:('Gn-pD;rK4.kK0', 'R3d,sOYXG !zR')
# Cromosoma: !SogTarIa,hM0 ------>  Aptitud: 3 --- Genes padres:('rP_RyVrtaaBz0', 'rP_RyVrtaaBz0')
# Cromosoma: Indymtrw2:y.0 ------>  Aptitud: 7 --- Genes padres:('In7Yñ1rWsÑzCs', 'b0dAPtrADÑ-.0')
# Cromosoma: Ir-us;ri;Wk 0 ------>  Aptitud: 6 --- Genes padres:('Iygpx Wizxjf0', 'tMZusarIFSqQ0')
# Cromosoma: rnzud!Iio,M,I ------>  Aptitud: 3 --- Genes padres:('tn0uw0Si-ÑGs9', 'tn0uw0Si-ÑGs9')
# Cromosoma: 6.iuktroh44E0 ------>  Aptitud: 5 --- Genes padres:('o2au8tJ2Zh6j0', '.-5FitrSÑM4Ñp')
# Cromosoma: InJUsgrñRÑaY0 ------>  Aptitud: 5 --- Genes padres:('ItXAylr0o;aT0', 'In ;ssr2rqIaI')
# Cromosoma: ImdJctria5-.0 ------>  Aptitud: 8 --- Genes padres:('IqMzPADia8R;0', ':ldpNtrHOqW-z')
# Cromosoma: IHd2s;rF! nU0 ------>  Aptitud: 6 --- Genes padres:('ItXAylr0o;aT0', 'R3d,sOYXG !zR')
# Cromosoma: v4IusFr9etHÑ0 ------>  Aptitud: 4 --- Genes padres:('tMZusarIFSqQ0', 'WUTTsñrcVNGb0')
# Cromosoma: IndEQcr,y-dN0 ------>  Aptitud: 5 --- Genes padres:('AndO4grJyhPp5', 'ItXAylr0o;aT0')
# Cromosoma: ñLdi9tr?afi.0 ------>  Aptitud: 6 --- Genes padres:(':VQWPtr2a9V:0', 'b0dAPtrADÑ-.0')
# Cromosoma: In5ustrr6lRs0 ------>  Aptitud: 7 --- Genes padres:(',Szustrh3ñzP0', 'In7Yñ1rWsÑzCs')
# Cromosoma: InEUsbrinUOr0 ------>  Aptitud: 6 --- Genes padres:('In ;ssr2rqIaI', 'IvÑbBkPi-xwñ0')
# Cromosoma: !SSusPrr0  R0 ------>  Aptitud: 5 --- Genes padres:('rF_usrr_zrXJ0', 'Añ_u3Z?49 Ey0')
# Cromosoma: I9;OMtFianh50 ------>  Aptitud: 5 --- Genes padres:('IqMzPADia8R;0', 'Ip!4GtFi1pY;z')
# Cromosoma: T;dzst4i? El0 ------>  Aptitud: 6 --- Genes padres:('R3d,sOYXG !zR', 'vqqyHt_iO8xh0')
# Cromosoma: Z6,uNtrXñ 6V0 ------>  Aptitud: 5 --- Genes padres:('5;RuDtrHkxr90', 'S8OEIt_Mz Ot0')
# Cromosoma: IndD_XriaELi0 ------>  Aptitud: 7 --- Genes padres:('Indd.PrI04M24', 'IqMzPADia8R;0')
# Cromosoma: 3nwu.tr-h,vF0 ------>  Aptitud: 5 --- Genes padres:('5;RuDtrHkxr90', ':n5uWtrAF_:iv')
# Cromosoma: IadWntri6zvna ------>  Aptitud: 5 --- Genes padres:('Ip!4GtFi1pY;z', ':ldpNtrHOqW-z')
# Cromosoma: IvuuFtri6TÑU0 ------>  Aptitud: 6 --- Genes padres:('Ip!4GtFi1pY;z', '5;RuDtrHkxr90')
# Cromosoma: ?ddqstujap4e0 ------>  Aptitud: 6 --- Genes padres:('fjdJst;KTV4QH', 'Q7sÑ9tYlaL1J0')
# Cromosoma: Indu¡trAlvy40 ------>  Aptitud: 7 --- Genes padres:('Isdluz0r¡S9;0', ':n5uWtrAF_:iv')
# Cromosoma: InE5vtriNZqkS ------>  Aptitud: 5 --- Genes padres:('IVoz¡tli!;u!b', 'In7Yñ1rWsÑzCs')
# Cromosoma: VngurtrRMT¿¡0 ------>  Aptitud: 5 --- Genes padres:(':n5uWtrAF_:iv', 'Gn-pD;rK4.kK0')
# Cromosoma: IHzueta;O 4j0 ------>  Aptitud: 6 --- Genes padres:(';1au8tQLN jz0', 'I_X5CtRBpZ4ye')
# Cromosoma: IfdettOD1p4I0 ------>  Aptitud: 5 --- Genes padres:('Isdluz0r¡S9;0', 'IkñXVt!;SN4ñQ')
# Cromosoma: IhdustuiJs490 ------>  Aptitud: 8 --- Genes padres:('Ir7uTV3ip45g0', 'fjdJst;KTV4QH')
# Cromosoma: InG8NtrFaXqb0 ------>  Aptitud: 6 --- Genes padres:('InFkI4r26ZPo0', ':VQWPtr2a9V:0')
# Cromosoma: IwPus¡r¿9W4p0 ------>  Aptitud: 6 --- Genes padres:('IF-usKrW!QTC0', 'IJJñuprPkb45H')
# Cromosoma: Lntus6rilzaF0 ------>  Aptitud: 6 --- Genes padres:('tn0uw0Si-ÑGs9', 'tMZusarIFSqQ0')
# Cromosoma: In8ñg0ria C80 ------>  Aptitud: 7 --- Genes padres:('Wn:.¿Ñr3b Et0', 'IqMzPADia8R;0')
# Cromosoma: IndbstriL1Y0U ------>  Aptitud: 7 --- Genes padres:('In ;ssr2rqIaI', 'IUd?QtviJMgc5')
# Cromosoma: vñduftvde 2!0 ------>  Aptitud: 5 --- Genes padres:('6gdtLtTO-¿PV0', ';1au8tQLN jz0')
# Cromosoma: sLOustrN6 T¡0 ------>  Aptitud: 6 --- Genes padres:('rF_usrr_zrXJ0', ';1au8tQLN jz0')
# Cromosoma: I!d st1io jd0 ------>  Aptitud: 7 --- Genes padres:('R3d,sOYXG !zR', 'IVoz¡tli!;u!b')
# Cromosoma: IaQustrXMq4C0 ------>  Aptitud: 7 --- Genes padres:(',Szustrh3ñzP0', 'IJJñuprPkb45H')
# Cromosoma: IÑ-YxtbisÑK20 ------>  Aptitud: 4 --- Genes padres:('vqqyHt_iO8xh0', 'Ip!4GtFi1pY;z')
# Cromosoma: Inpustr!ñAV;0 ------>  Aptitud: 7 --- Genes padres:(':n5uWtrAF_:iv', 'IF-usKrW!QTC0')
# Cromosoma: IC6uNtria7kv0 ------>  Aptitud: 7 --- Genes padres:(':VQWPtr2a9V:0', 'Ir7uTV3ip45g0')
# Cromosoma: Inmusbri.YCe0 ------>  Aptitud: 7 --- Genes padres:('Ir7uTV3ip45g0', 'onousrrcrrLLV')
# Cromosoma: IpdwDtniD m 0 ------>  Aptitud: 6 --- Genes padres:('S8OEIt_Mz Ot0', 'IUd?QtviJMgc5')
# Cromosoma: IndqstrÑGz4Ns ------>  Aptitud: 7 --- Genes padres:('AndO4grJyhPp5', 'I_X5CtRBpZ4ye')
# Cromosoma: lBluqtrZau:.0 ------>  Aptitud: 6 --- Genes padres:(':VQWPtr2a9V:0', '5;RuDtrHkxr90')
# Cromosoma: In6MstrE¡P4Ew ------>  Aptitud: 6 --- Genes padres:('I_X5CtRBpZ4ye', 'In ;ssr2rqIaI')
# Cromosoma: IbPus0rW:Ikm0 ------>  Aptitud: 5 --- Genes padres:('IF-usKrW!QTC0', 'tMZusarIFSqQ0')
# Cromosoma: In3FdDrim ft0 ------>  Aptitud: 6 --- Genes padres:('Wn:.¿Ñr3b Et0', 'IvÑbBkPi-xwñ0')
# Cromosoma: I.A:2triafHJ0 ------>  Aptitud: 6 --- Genes padres:(':VQWPtr2a9V:0', 'Iygpx Wizxjf0')
# Devolviendo cromosomas aptos
# Generando proxima generacion
# Cromosoma: InHustri 4KC0 ------>  Aptitud: 8 --- Genes padres:(';VOustrifFT70', 'IncusñrQTX0H0')
# Cromosoma: Ihduhtria CC0 ------>  Aptitud: 9 --- Genes padres:('INduptfi1 ET0', 'IC6uNtria7kv0')
# Cromosoma: InduBEriB14H0 ------>  Aptitud: 8 --- Genes padres:('IqLuvhrixd4H0', 'InduOErZ4EI30')
# Cromosoma: IndustYij ,c0 ------>  Aptitud: 9 --- Genes padres:('3n:uBtNi¿ 3V0', 'I!d st1io jd0')
# Cromosoma: Inlustrig?;80 ------>  Aptitud: 8 --- Genes padres:('IvuuFtri6TÑU0', 'In5ustrr6lRs0')
# Cromosoma: IC¿ustria eÑ0 ------>  Aptitud: 9 --- Genes padres:('tq5udtrna YM0', 'IuQustria00T0')
# Cromosoma: In,ustri-4yh0 ------>  Aptitud: 8 --- Genes padres:('Inmusbri.YCe0', 'In5ustrr6lRs0')
# Cromosoma: RNdustrsaWx.0 ------>  Aptitud: 8 --- Genes padres:('uDdubtruNy,.0', 'ñLdi9tr?afi.0')
# Cromosoma: Inhustria pg0 ------>  Aptitud: 10 --- Genes padres:('In8ñg0ria C80', 'IWzustriE9ZM0')
# Cromosoma: I,dustri Qg.0 ------>  Aptitud: 9 --- Genes padres:('IWzustriE9ZM0', 'uDdubtruNy,.0')
# Cromosoma: IndsstriL F;0 ------>  Aptitud: 9 --- Genes padres:('kndhsmram NF0', 'IndbstriL1Y0U')
# Cromosoma: xndustri9 Zx0 ------>  Aptitud: 9 --- Genes padres:('¿ndwOtrnf 7R0', ';VOustrifFT70')
# Cromosoma: IndustriQv410 ------>  Aptitud: 10 --- Genes padres:('Indakjr2NB490', 'IWzustriE9ZM0')
# Cromosoma: IndRstria ia0 ------>  Aptitud: 10 --- Genes padres:('I!d st1io jd0', ':nf-Ytrda zf0')
# Cromosoma: IndustriDp4Ñ0 ------>  Aptitud: 10 --- Genes padres:('IndqstrÑGz4Ns', 'IhdustuiJs490')
# Cromosoma: IndusZrUZ rA0 ------>  Aptitud: 8 --- Genes padres:('kndhsmram NF0', 'InduOErZ4EI30')
# Cromosoma: Inlustria64-0 ------>  Aptitud: 10 --- Genes padres:('InqVstrTÑA4dZ', 'IuQustria00T0')
# Cromosoma: IndustriL 4c0 ------>  Aptitud: 11 --- Genes padres:('IYWus_rU. aO0', 'IndqstrÑGz4Ns')
# Cromosoma: I1dustrñrJ4.0 ------>  Aptitud: 9 --- Genes padres:('IaQustrXMq4C0', 'uDdubtruNy,.0')
# Cromosoma: InauztriH 4F0 ------>  Aptitud: 9 --- Genes padres:('4nFuytYi90400', 'InQuitriS 6A0')
# Cromosoma: In-ustri1YoW0 ------>  Aptitud: 8 --- Genes padres:('In5ustrr6lRs0', ';VOustrifFT70')
# Cromosoma: InaustrDa 4X0 ------>  Aptitud: 10 --- Genes padres:(':nf-Ytrda zf0', 'IaQustrXMq4C0')
# Cromosoma: Industrx- 4T0 ------>  Aptitud: 10 --- Genes padres:('IbdD,trxpd4O0', '4n7usYrwO Sk0')
# Cromosoma: Indus8r,Iñ4v0 ------>  Aptitud: 8 --- Genes padres:('IncusñrQTX0H0', 'Indakjr2NB490')
# Cromosoma: IndYptr8HV4¡0 ------>  Aptitud: 7 --- Genes padres:('IbdD,trxpd4O0', 'Indakjr2NB490')
# Cromosoma: IndxñtrwI G.0 ------>  Aptitud: 8 --- Genes padres:('Indymtrw2:y.0', '¿ndwOtrnf 7R0')
# Cromosoma: IndustriG _B0 ------>  Aptitud: 10 --- Genes padres:('T;dzst4i? El0', 'Inmusbri.YCe0')
# Cromosoma: In;ustriuz300 ------>  Aptitud: 8 --- Genes padres:(';VOustrifFT70', 'Inpustr!ñAV;0')
# Cromosoma: mnSustrn_ 7X0 ------>  Aptitud: 7 --- Genes padres:('dnEustro. Kq0', '4n7usYrwO Sk0')
# Cromosoma: I¡8usariL Yh0 ------>  Aptitud: 7 --- Genes padres:('IYWus_rU. aO0', 'Ir-us;ri;Wk 0')
# Cromosoma: IVdustri_ ,.0 ------>  Aptitud: 10 --- Genes padres:('INduptfi1 ET0', 'Ibdustrij9AT0')
# Cromosoma: IJd5stria 480 ------>  Aptitud: 10 --- Genes padres:('T;dzst4i? El0', 'I97Y7sriaN4Ñ0')
# Cromosoma: IcdustriY .U0 ------>  Aptitud: 9 --- Genes padres:('T;dzst4i? El0', 'IvuuFtri6TÑU0')
# Cromosoma: IIdMdtriay4.0 ------>  Aptitud: 9 --- Genes padres:('ImdJctria5-.0', 'I97Y7sriaN4Ñ0')
# Cromosoma: InductrO36F.0 ------>  Aptitud: 8 --- Genes padres:('Indymtrw2:y.0', 'Indu¡trAlvy40')
# Cromosoma: IAdustri, KG0 ------>  Aptitud: 9 --- Genes padres:('Ibdustrij9AT0', 'I!d st1io jd0')
# Cromosoma: InduTtriejc.0 ------>  Aptitud: 9 --- Genes padres:('IvuuFtri6TÑU0', 'Indymtrw2:y.0')
# Cromosoma: Indu0tri8 U.0 ------>  Aptitud: 10 --- Genes padres:('Indu¡trAlvy40', '3n:uBtNi¿ 3V0')
# Cromosoma: IndustriS08K0 ------>  Aptitud: 9 --- Genes padres:('IWzustriE9ZM0', 'IndbstriL1Y0U')
# Cromosoma: Indu9tria 4p0 ------>  Aptitud: 11 --- Genes padres:(':nf-Ytrda zf0', 'IqLuvhrixd4H0')
# Cromosoma: Industrimq4g0 ------>  Aptitud: 10 --- Genes padres:('InEUsbrinUOr0', 'IhdustuiJs490')
# Cromosoma: Inyustria ?b0 ------>  Aptitud: 10 --- Genes padres:('Ir-us;ri;Wk 0', ':nf-Ytrda zf0')
# Cromosoma: InHustria 4W0 ------>  Aptitud: 11 --- Genes padres:('IaQustrXMq4C0', 'InQuitriS 6A0')
# Cromosoma: InCXihria 4q0 ------>  Aptitud: 8 --- Genes padres:('In8ñg0ria C80', 'I97Y7sriaN4Ñ0')
# Cromosoma: IBdjstria c.0 ------>  Aptitud: 10 --- Genes padres:('IHd2s;rF! nU0', 'ImdJctria5-.0')
# Cromosoma: IDdustrPJH4 0 ------>  Aptitud: 8 --- Genes padres:('IbdD,trxpd4O0', 'IaQustrXMq4C0')
# Cromosoma: In8uqXria 4;0 ------>  Aptitud: 9 --- Genes padres:('IqLuvhrixd4H0', 'In8ñg0ria C80')
# Cromosoma: Ind¡str3Yd4.0 ------>  Aptitud: 9 --- Genes padres:('Indymtrw2:y.0', 'InqVstrTÑA4dZ')
# Cromosoma: IddustriÑ;4z0 ------>  Aptitud: 9 --- Genes padres:('IhdustuiJs490', 'IqLuvhrixd4H0')
# Cromosoma: In1ustrikCq30 ------>  Aptitud: 8 --- Genes padres:('IncusñrQTX0H0', ';VOustrifFT70')
# Cromosoma: I3dustrLaS4.0 ------>  Aptitud: 10 --- Genes padres:('ñLdi9tr?afi.0', 'IaQustrXMq4C0')
# Cromosoma: Ifdustria7M.0 ------>  Aptitud: 10 --- Genes padres:('ñLdi9tr?afi.0', 'IWzustriE9ZM0')
# Cromosoma: Indystriam!70 ------>  Aptitud: 9 --- Genes padres:('InEUsbrinUOr0', 'ICd:ktxiaHNK0')
# Cromosoma: InIustriv _A0 ------>  Aptitud: 9 --- Genes padres:('dnEustro. Kq0', 'Inmusbri.YCe0')
# Cromosoma: InYu:triD 4A0 ------>  Aptitud: 9 --- Genes padres:('InQuitriS 6A0', 'INguÑtrFf 4a0')
# Cromosoma: Itdustria ¡f0 ------>  Aptitud: 10 --- Genes padres:('IuQustria00T0', 'INduptfi1 ET0')
# Cromosoma: InMustrV;oDJ0 ------>  Aptitud: 7 --- Genes padres:('InCusUrb;4Og0', 'Inpustr!ñAV;0')
# Cromosoma: In usCria De0 ------>  Aptitud: 9 --- Genes padres:('Ir-us;ri;Wk 0', 'In8ñg0ria C80')
# Cromosoma: ,ndu.trUa e20 ------>  Aptitud: 8 --- Genes padres:('tq5udtrna YM0', '¿ndwOtrnf 7R0')
# Cromosoma: InÑ sKriT ?S0 ------>  Aptitud: 7 --- Genes padres:('In!3sVriJ Q¿0', 'InEUsbrinUOr0')
# Cromosoma: Industria Yq0 ------>  Aptitud: 11 --- Genes padres:('ICd:ktxiaHNK0', 'dnEustro. Kq0')
# Cromosoma: Isdustr¿aU4_0 ------>  Aptitud: 9 --- Genes padres:('?ddqstujap4e0', 'IaQustrXMq4C0')
# Cromosoma: IY3uktria84D0 ------>  Aptitud: 8 --- Genes padres:('I97Y7sriaN4Ñ0', 'IC6uNtria7kv0')
# Cromosoma: InFus2ri¡nHo0 ------>  Aptitud: 7 --- Genes padres:('Inmusbri.YCe0', 'Ir-us;ri;Wk 0')
# Cromosoma: InwustribVIb0 ------>  Aptitud: 8 --- Genes padres:('Ix¿ustriñ8GF0', 'InEUsbrinUOr0')
# Cromosoma: IndustrW-0eU0 ------>  Aptitud: 8 --- Genes padres:('Indu¡trAlvy40', 'Inpustr!ñAV;0')
# Cromosoma: Industryzg4z0 ------>  Aptitud: 9 --- Genes padres:('IndqstrÑGz4Ns', 'IaQustrXMq4C0')
# Cromosoma: In0ustriM ¡,0 ------>  Aptitud: 9 --- Genes padres:('InQuitriS 6A0', 'InCusUrb;4Og0')
# Cromosoma: IndIstriH K90 ------>  Aptitud: 9 --- Genes padres:('IHd2s;rF! nU0', '¿ndwOtrnf 7R0')
# Cromosoma: IndustriaI4j0 ------>  Aptitud: 11 --- Genes padres:('IhdustuiJs490', 'IndD_XriaELi0')
# Cromosoma: IjdustriM 4;0 ------>  Aptitud: 10 --- Genes padres:('IhdustuiJs490', 'INguÑtrFf 4a0')
# Cromosoma: Industria 4V0 ------>  Aptitud: 12 --- Genes padres:('InQuitriS 6A0', '?ddqstujap4e0')
# Cromosoma: IndustriLJ¡d0 ------>  Aptitud: 9 --- Genes padres:('Inmusbri.YCe0', 'Ibdustrij9AT0')
# Cromosoma: I-dustriapE;0 ------>  Aptitud: 9 --- Genes padres:('ICd:ktxiaHNK0', 'IuQustria00T0')
# Cromosoma: IndDstriG 4ñ0 ------>  Aptitud: 10 --- Genes padres:('In!3sVriJ Q¿0', 'IndqstrÑGz4Ns')
# Cromosoma: In9ustrixfi80 ------>  Aptitud: 8 --- Genes padres:('InEUsbrinUOr0', 'In5ustrr6lRs0')
# Cromosoma: JnduDtriG Nz0 ------>  Aptitud: 8 --- Genes padres:('3n:uBtNi¿ 3V0', '¿ndwOtrnf 7R0')
# Cromosoma: Industri8 w00 ------>  Aptitud: 10 --- Genes padres:('Inpustr!ñAV;0', 'INduptfi1 ET0')
# Cromosoma: Indjsfria Wx0 ------>  Aptitud: 9 --- Genes padres:('IHd2s;rF! nU0', 'IndD_XriaELi0')
# Cromosoma: IW!uHtriaL4Y0 ------>  Aptitud: 8 --- Genes padres:('IvuuFtri6TÑU0', 'I97Y7sriaN4Ñ0')
# Cromosoma: In2wstria YV0 ------>  Aptitud: 9 --- Genes padres:('InEUsbrinUOr0', ':nf-Ytrda zf0')
# Cromosoma: I2d,stIiaw4D0 ------>  Aptitud: 8 --- Genes padres:('?ddqstujap4e0', 'ICd:ktxiaHNK0')
# Cromosoma: InRustr_UrFB0 ------>  Aptitud: 7 --- Genes padres:('IncusñrQTX0H0', 'Inpustr!ñAV;0')
# Cromosoma: FnIustriF dh0 ------>  Aptitud: 8 --- Genes padres:('dnEustro. Kq0', ';VOustrifFT70')
# Cromosoma: InPustriJ SH0 ------>  Aptitud: 9 --- Genes padres:('InQuitriS 6A0', 'InCusUrb;4Og0')
# Cromosoma: Indjstria TR0 ------>  Aptitud: 10 --- Genes padres:('ICd:ktxiaHNK0', 'In!3sVriJ Q¿0')
# Cromosoma: Iud5stria 4R0 ------>  Aptitud: 10 --- Genes padres:('I97Y7sriaN4Ñ0', '?ddqstujap4e0')
# Cromosoma: IndustriBCA.0 ------>  Aptitud: 10 --- Genes padres:('Indymtrw2:y.0', 'Ibdustrij9AT0')
# Cromosoma: GTyuktr?a ¡W0 ------>  Aptitud: 6 --- Genes padres:('tq5udtrna YM0', 'tq5udtrna YM0')
# Cromosoma: In!u tria 4T0 ------>  Aptitud: 10 --- Genes padres:('INguÑtrFf 4a0', 'In8ñg0ria C80')
# Devolviendo cromosomas aptos
# Generando proxima generacion
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('Inyustria ?b0', 'IIdMdtriay4.0')
# Cromosoma: IndustrieR4U0 ------>  Aptitud: 10 --- Genes padres:('IddustriÑ;4z0', 'Industrimq4g0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('InHustria 4W0', 'IBdjstria c.0')
# Cromosoma: Industria ¿y0 ------>  Aptitud: 11 --- Genes padres:('xndustri9 Zx0', 'Ihduhtria CC0')
# Cromosoma: Industri¡ 400 ------>  Aptitud: 11 --- Genes padres:('InYu:triD 4A0', 'IndustriDp4Ñ0')
# Cromosoma: Industriv 4.0 ------>  Aptitud: 12 --- Genes padres:('IndDstriG 4ñ0', 'IVdustri_ ,.0')
# Cromosoma: IndustriI 4.0 ------>  Aptitud: 12 --- Genes padres:('InYu:triD 4A0', 'IVdustri_ ,.0')
# Cromosoma: Industria cr0 ------>  Aptitud: 11 --- Genes padres:('Inyustria ?b0', 'IndsstriL F;0')
# Cromosoma: Industria 490 ------>  Aptitud: 12 --- Genes padres:('IndRstria ia0', 'IndustriDp4Ñ0')
# Cromosoma: Industria Ca0 ------>  Aptitud: 11 --- Genes padres:('Indjstria TR0', 'Itdustria ¡f0')
# Cromosoma: Iqdustria m.0 ------>  Aptitud: 11 --- Genes padres:('I,dustri Qg.0', 'Ihduhtria CC0')
# Cromosoma: Industria 4¿0 ------>  Aptitud: 12 --- Genes padres:('InauztriH 4F0', 'IndustriaI4j0')
# Cromosoma: I;dustriI34.0 ------>  Aptitud: 10 --- Genes padres:('IddustriÑ;4z0', 'I,dustri Qg.0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('IndustriG _B0', 'IIdMdtriay4.0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('Ind¡str3Yd4.0', 'In8uqXria 4;0')
# Cromosoma: Industria14p0 ------>  Aptitud: 11 --- Genes padres:('Indystriam!70', 'IndustriQv410')
# Cromosoma: IndLstria 4n0 ------>  Aptitud: 11 --- Genes padres:('IndDstriG 4ñ0', 'IJd5stria 480')
# Cromosoma: Industria 4g0 ------>  Aptitud: 12 --- Genes padres:('IndustriL 4c0', 'Iud5stria 4R0')
# Cromosoma: Industria 4d0 ------>  Aptitud: 12 --- Genes padres:('InauztriH 4F0', 'Indystriam!70')
# Cromosoma: I4dustria 4ñ0 ------>  Aptitud: 11 --- Genes padres:('Iud5stria 4R0', 'IAdustri, KG0')
# Cromosoma: IndustriV ¡W0 ------>  Aptitud: 10 --- Genes padres:('IndustYij ,c0', 'IcdustriY .U0')
# Cromosoma: Industria 4C0 ------>  Aptitud: 12 --- Genes padres:('In8uqXria 4;0', 'Iud5stria 4R0')
# Cromosoma: Industria 4X0 ------>  Aptitud: 12 --- Genes padres:('InHustria 4W0', 'IndustriS08K0')
# Cromosoma: I-uustria Hb0 ------>  Aptitud: 9 --- Genes padres:('IC¿ustria eÑ0', 'IC¿ustria eÑ0')
# Cromosoma: Industria 4c0 ------>  Aptitud: 12 --- Genes padres:('IndustriQv410', 'In usCria De0')
# Cromosoma: Industria 4F0 ------>  Aptitud: 12 --- Genes padres:('IC¿ustria eÑ0', 'IndustriL 4c0')
# Cromosoma: I7dustri3 4.0 ------>  Aptitud: 11 --- Genes padres:('IVdustri_ ,.0', 'IddustriÑ;4z0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('In8uqXria 4;0', 'I,dustri Qg.0')
# Cromosoma: Inzustria 4i0 ------>  Aptitud: 11 --- Genes padres:('InHustria 4W0', 'In usCria De0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('In8uqXria 4;0', 'I1dustrñrJ4.0')
# Cromosoma: I:dustrif 4.0 ------>  Aptitud: 11 --- Genes padres:('I1dustrñrJ4.0', 'IVdustri_ ,.0')
# Cromosoma: Industrid 4F0 ------>  Aptitud: 11 --- Genes padres:('IcdustriY .U0', 'IndDstriG 4ñ0')
# Cromosoma: Incustria Zu0 ------>  Aptitud: 10 --- Genes padres:('Inhustria pg0', 'IC¿ustria eÑ0')
# Cromosoma: Industria 4a0 ------>  Aptitud: 12 --- Genes padres:('In!u tria 4T0', 'IndustriG _B0')
# Cromosoma: Industri4 4.0 ------>  Aptitud: 12 --- Genes padres:('Industri8 w00', 'I1dustrñrJ4.0')
# Cromosoma: Industria34.0 ------>  Aptitud: 12 --- Genes padres:('Ind¡str3Yd4.0', 'Inlustria64-0')
# Cromosoma: Industria 4m0 ------>  Aptitud: 12 --- Genes padres:('IjdustriM 4;0', 'In usCria De0')
# Cromosoma: Industrig 4l0 ------>  Aptitud: 11 --- Genes padres:('Industri8 w00', 'InauztriH 4F0')
# Cromosoma: Industria 450 ------>  Aptitud: 12 --- Genes padres:('IddustriÑ;4z0', 'Inyustria ?b0')
# Cromosoma: Industria Tg0 ------>  Aptitud: 11 --- Genes padres:('Indystriam!70', 'IcdustriY .U0')
# Cromosoma: I4dustria 4_0 ------>  Aptitud: 11 --- Genes padres:('IC¿ustria eÑ0', 'Iud5stria 4R0')
# Cromosoma: Industria 4c0 ------>  Aptitud: 12 --- Genes padres:('In usCria De0', 'IjdustriM 4;0')
# Cromosoma: Ind_stria 4ñ0 ------>  Aptitud: 11 --- Genes padres:('Indystriam!70', 'IndDstriG 4ñ0')
# Cromosoma: Industria 4_0 ------>  Aptitud: 12 --- Genes padres:('IndustriaI4j0', 'Industrx- 4T0')
# Cromosoma: Iudustria 4.0 ------>  Aptitud: 12 --- Genes padres:('IBdjstria c.0', 'IjdustriM 4;0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('InHustria 4W0', 'IBdjstria c.0')
# Cromosoma: Industriakr.0 ------>  Aptitud: 11 --- Genes padres:('Indystriam!70', 'IndustriBCA.0')
# Cromosoma: Industria 4¡0 ------>  Aptitud: 12 --- Genes padres:('InaustrDa 4X0', 'IJd5stria 480')
# Cromosoma: Industri_ CC0 ------>  Aptitud: 10 --- Genes padres:('xndustri9 Zx0', 'InIustriv _A0')
# Cromosoma: Industria 4Y0 ------>  Aptitud: 12 --- Genes padres:('IndustriG _B0', 'In8uqXria 4;0')
# Cromosoma: Industria tg0 ------>  Aptitud: 11 --- Genes padres:('IAdustri, KG0', 'Indjstria TR0')
# Cromosoma: I?dustria 4Ñ0 ------>  Aptitud: 11 --- Genes padres:('Iud5stria 4R0', 'IAdustri, KG0')
# Cromosoma: IndustriN _00 ------>  Aptitud: 10 --- Genes padres:('IndustriG _B0', 'IndustYij ,c0')
# Cromosoma: IKdHstria 4C0 ------>  Aptitud: 10 --- Genes padres:('IJd5stria 480', 'IJd5stria 480')
# Cromosoma: Industria 4x0 ------>  Aptitud: 12 --- Genes padres:('InHustria 4W0', 'IndustriDp4Ñ0')
# Cromosoma: Industria 400 ------>  Aptitud: 12 --- Genes padres:('Industrx- 4T0', 'Industria Yq0')
# Cromosoma: Industria 4t0 ------>  Aptitud: 12 --- Genes padres:('xndustri9 Zx0', 'InaustrDa 4X0')
# Cromosoma: Industria ¡c0 ------>  Aptitud: 11 --- Genes padres:('Itdustria ¡f0', 'Industri8 w00')
# Cromosoma: Industria ñY0 ------>  Aptitud: 11 --- Genes padres:('Indjstria TR0', 'InIustriv _A0')
# Cromosoma: Industria L00 ------>  Aptitud: 11 --- Genes padres:('In usCria De0', 'IcdustriY .U0')
# Cromosoma: Industria 4b0 ------>  Aptitud: 12 --- Genes padres:('IndustriaI4j0', 'IndustYij ,c0')
# Cromosoma: Industria 4B0 ------>  Aptitud: 12 --- Genes padres:('Industria 4V0', 'Inyustria ?b0')
# Cromosoma: In5ustria 4y0 ------>  Aptitud: 11 --- Genes padres:('InauztriH 4F0', 'Inhustria pg0')
# Cromosoma: Induztria 4 0 ------>  Aptitud: 11 --- Genes padres:('InYu:triD 4A0', 'Indu9tria 4p0')
# Cromosoma: Industri- 4-0 ------>  Aptitud: 11 --- Genes padres:('InYu:triD 4A0', 'IndDstriG 4ñ0')
# Cromosoma: IndustriT 4T0 ------>  Aptitud: 11 --- Genes padres:('IndustriDp4Ñ0', 'IndDstriG 4ñ0')
# Cromosoma: Industria 4¿0 ------>  Aptitud: 12 --- Genes padres:('In usCria De0', 'IjdustriM 4;0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('Ind¡str3Yd4.0', 'IC¿ustria eÑ0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('Ifdustria7M.0', 'Indu9tria 4p0')
# Cromosoma: Industria 4y0 ------>  Aptitud: 12 --- Genes padres:('IndRstria ia0', 'IddustriÑ;4z0')
# Cromosoma: Industria UL0 ------>  Aptitud: 11 --- Genes padres:('IndsstriL F;0', 'Industria Yq0')
# Cromosoma: InIustria 4H0 ------>  Aptitud: 11 --- Genes padres:('Inyustria ?b0', 'InHustria 4W0')
# Cromosoma: Industria 4!0 ------>  Aptitud: 12 --- Genes padres:('IjdustriM 4;0', 'Industria 4V0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('InaustrDa 4X0', 'IIdMdtriay4.0')
# Cromosoma: Industria ¿v0 ------>  Aptitud: 11 --- Genes padres:('In usCria De0', 'Indystriam!70')
# Cromosoma: Industria 4a0 ------>  Aptitud: 12 --- Genes padres:('Industrx- 4T0', 'Ihduhtria CC0')
# Cromosoma: Industri? 4l0 ------>  Aptitud: 11 --- Genes padres:('IcdustriY .U0', 'Industrx- 4T0')
# Cromosoma: IndustriM mk0 ------>  Aptitud: 10 --- Genes padres:('Industri8 w00', 'InIustriv _A0')
# Cromosoma: Industria y.0 ------>  Aptitud: 12 --- Genes padres:('InduTtriejc.0', 'IBdjstria c.0')
# Cromosoma: IDduntria 4.0 ------>  Aptitud: 11 --- Genes padres:('IIdMdtriay4.0', 'Ihduhtria CC0')
# Cromosoma: Industria 4r0 ------>  Aptitud: 12 --- Genes padres:('IndustriL 4c0', 'Industria Yq0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('IBdjstria c.0', 'Inlustria64-0')
# Cromosoma: Industrin 490 ------>  Aptitud: 11 --- Genes padres:('Industrimq4g0', 'IcdustriY .U0')
# Cromosoma: Industria 430 ------>  Aptitud: 12 --- Genes padres:('Inhustria pg0', 'Industrimq4g0')
# Cromosoma: Industria 4.0 ------>  Aptitud: 13 --- Genes padres:('Inhustria pg0', 'Industria 4V0')
# Cromosoma: Industris 4.0 ------>  Aptitud: 12 --- Genes padres:('Ind¡str3Yd4.0', 'IVdustri_ ,.0')
# Cromosoma: Industria 4c0 ------>  Aptitud: 12 --- Genes padres:('IndustriQv410', 'Inhustria pg0')
# Cromosoma: Indu;tria 4.0 ------>  Aptitud: 12 --- Genes padres:('Indu0tri8 U.0', 'Indu9tria 4p0')
# Cromosoma: Industrie 4.0 ------>  Aptitud: 12 --- Genes padres:('IVdustri_ ,.0', 'Industrimq4g0')
# Cromosoma: Industria Q10 ------>  Aptitud: 11 --- Genes padres:('Indystriam!70', 'IC¿ustria eÑ0')
# Industria 4.0
